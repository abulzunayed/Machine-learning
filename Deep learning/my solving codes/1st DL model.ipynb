# %%
import numpy as np

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_circles

# %%
X,y= make_circles(n_samples=1000, noise=0.1, random_state=0, factor=0.2)

# %%
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %%
model = Sequential()

# %%
model.add(Dense(4, input_shape=(2,), activation='tanh'))

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(SGD(learning_rate=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 32/32 [==============================] - 1s 1ms/step - loss: 0.6936 - accuracy: 0.5990
# Epoch 2/20
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6640 - accuracy: 0.7380
# Epoch 3/20
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5994 - accuracy: 0.7770
# Epoch 4/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5085 - accuracy: 0.8410
# Epoch 5/20
# 32/32 [==============================] - 0s 901us/step - loss: 0.4381 - accuracy: 0.8550
# Epoch 6/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4000 - accuracy: 0.8640
# Epoch 7/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3725 - accuracy: 0.8630
# Epoch 8/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3587 - accuracy: 0.8660
# Epoch 9/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3505 - accuracy: 0.8700
# Epoch 10/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3465 - accuracy: 0.8680
# Epoch 11/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3409 - accuracy: 0.8700
# Epoch 12/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3355 - accuracy: 0.8670
# Epoch 13/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3339 - accuracy: 0.8760
# Epoch 14/20
# 32/32 [==============================] - 0s 933us/step - loss: 0.3302 - accuracy: 0.8670
# Epoch 15/20
# 32/32 [==============================] - 0s 869us/step - loss: 0.3269 - accuracy: 0.8710
# Epoch 16/20
# 32/32 [==============================] - 0s 885us/step - loss: 0.3259 - accuracy: 0.8690
# Epoch 17/20
# 32/32 [==============================] - 0s 965us/step - loss: 0.3254 - accuracy: 0.8750
# Epoch 18/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3140 - accuracy: 0.8710
# Epoch 19/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2859 - accuracy: 0.8810
# Epoch 20/20
# 32/32 [==============================] - 0s 869us/step - loss: 0.2186 - accuracy: 0.9090

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([1, 3, 2, 4])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
A= np.array([[1, 2, 3], [4,5,6]])
B=np.array([ [1,2],[3,4],[5,6]])

C= np.array([ [1,2],[3,4],[5,6], [7,8]])

print( "A is a {} matrix".format(A.shape))
print( "B is a {} matrix".format(B.shape))
print( "C is a {} matrix".format(C.shape))
# Out:
# A is a (2, 3) matrix
# B is a (3, 2) matrix
# C is a (4, 2) matrix

# %%
A[0]
# Out:
# array([3, 1, 2])

# %%
A[1,2]
# Out:
# 4

# %%
A[:, 1]
# Out:
# array([1, 3])

# %%
# elementwise operation
3*A
# Out:
# array([[ 9,  3,  6],
#        [ 6,  9, 12]])

# %%
A+A
# Out:
# array([[6, 2, 4],
#        [4, 6, 8]])

# %%
A/2
# Out:
# array([[1.5, 0.5, 1. ],
#        [1. , 1.5, 2. ]])

# %%
A*B
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29540\786576050.py in <module>
# ----> 1 A*B
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,2)

# %%
# Dot product possible
A.dot(B)
# Out:
# array([[22, 28],
#        [49, 64]])

# %%
B=np.array( [ [2,2],[2,3]])
A=np.array( [  [1,2,3], [4,5,6]  ])

# %%
B.dot(A)
# Out:
# array([[10, 14, 18],
#        [14, 19, 24]])

# %%
np.dot(B,A)
# Out:
# array([[10, 14, 18],
#        [14, 19, 24]])

# %%
dflist = [ ]
lear= [0.1, 0.3, 0.4, 0.5]
for lr in lear:
    print(lr)
# Out:
# 0.1
# 0.3
# 0.4
# 0.5
